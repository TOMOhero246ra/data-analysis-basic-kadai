# %%
import numpy as np
A = np.array([[0 , 1], [2, 3], [4, 5]])
B = np.array([[0, 1, 2 ,3], [4, 5, 6 , 7]])
enzan = np.dot(A, B)
saidaichi = np.dot(A, B).max()

enzan
# Out:
# array([[ 4,  5,  6,  7],
#        [12, 17, 22, 27],
#        [20, 29, 38, 47]])

# %%
saidaichi
# Out:
# np.int64(47)
